# %%
#Imports
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display
from matplotlib.widgets import Slider
from matplotlib.widgets import CheckButtons,AxesWidget
import warnings
import matplotlib.cbook
import mysql.connector ,sys
# %matplotlib nbagg

# %% [markdown]
# # Flats Constructed (Data)

# %%
title = "Flat Constructed"
titlelen = len(title)
print("{:*^{titlelen}}".format(title, titlelen=titlelen+6))
print()

data = np.genfromtxt('DataProject/flats-constructed-by-housing-and-development-board-annual.csv',  
                               skip_header=1, 
                               dtype=[('year','U4'),  ('flat_constructed','i4')], delimiter=",",
                               missing_values=['na'],filling_values=0)


print("There are {} rows in this dataset".format(len(data)))
print()

set_year = set(data['year']) 
set_flat_constructed = set(data['flat_constructed'])


print(str(len(set_year)) + " unique values in year column")
print(str(len(set_flat_constructed)) + " unique values in flat_constructed column")

max_value = np.max(data['flat_constructed'])
min_value = np.min(data['flat_constructed'])         

max_row_index = np.argmax(data['flat_constructed'])
min_row_index = np.argmin(data['flat_constructed'])

std = np.std(data['flat_constructed'])
var = np.var(data['flat_constructed'])

print()

print("The mean number of flat constructed over the years is {:.0f}".format(np.mean(data['flat_constructed'])))

print("The maximum number of flat constructed was in the year {} is {}".format(data[max_row_index][0],data[max_row_index][1]))
print("The minimum number of flat constructed was in the year {} is {}".format(data[min_row_index][0],data[min_row_index][1]))

print("The standard deviation is {:.0f}".format(std))
print("The Variance is {:.0f}".format(var))
# Out:
# ***Flat Constructed***
#
# There are 40 rows in this dataset
#
# 40 unique values in year column
# 40 unique values in flat_constructed column
#
# The mean number of flat constructed over the years is 22068
# The maximum number of flat constructed was in the year 1984 is 67017
# The minimum number of flat constructed was in the year 2006 is 2733
# The standard deviation is 13054
# The Variance is 170401742

# %% [markdown]
# # Flat Constructed (Line Chart)

# %%
data = np.genfromtxt('DataProject/flats-constructed-by-housing-and-development-board-annual.csv',
                               skip_header=1,
                               dtype=[('year','i4'),  ('flat_constructed','i4')], delimiter=",",
                               missing_values=['na'],filling_values=0)

x_year = data['year']
y_flat_constructed = data['flat_constructed']

fig = plt.figure(figsize=(9,5))
ax = plt.subplot() 
ax.plot(x_year, y_flat_constructed, label='Flat Constructed',marker='o')
ax.set_xticks(range(min(x_year),max(x_year),5))
plt.ylabel('Number of Flat Constructed')
plt.xlabel('Year')

plt.legend(loc=0);
plt.title("Flat Constructed")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# # number of sold and rented residential units (Data)

# %% [markdown]
# # Different between Rented and Sold Units by Year (Bar Chart)

# %%
title = "Number of Sold and Rented Residential Units"
titlelen = len(title)
print("{:*^{titlelen}}".format(title, titlelen=titlelen+6))
print()

data = np.genfromtxt('DataProject/number-of-sold-and-rented-residential-units.csv',  
                skip_header=1, 
                dtype=[('year','i4'),  ('property_type','U4'), ('sold_or_rented','U6'), ('flat_type','U50'), 
                       ('no_of_units','i4')], delimiter=",",
                missing_values=['na','-'],filling_values=0)

#Never sort yet
print("There are {} rows in this dataset".format(len(data)))
print()

set_year = set(data['year'])
set_property_type = set(data['property_type'])
set_sold_or_rented = set(data['sold_or_rented'])
set_flat_type = set(data['flat_type'])
set_no_of_units = set(data['no_of_units'])

print(str(len(set_year)) + " unique values in year column")
print(str(len(set_property_type)) + " unique values in property_type column")
print(str(len(set_sold_or_rented)) + " unique values in sold_or_rented column")
print(str(len(set_flat_type)) + " unique values in flat_type column")
print(str(len(set_no_of_units)) + " unique values in no_of_units column")

max_value = np.max(data['no_of_units'])
max_row_index = np.argmax(data['no_of_units'])

 
std = np.std(data['no_of_units'])
var = np.var(data['no_of_units'])

print()

print("The mean number of flat sold/rented over the years is {:.0f}".format(np.mean(data['no_of_units'])))
print("The maximum number of flat sold/rented was in the year {} is {} on {}".format(data[max_row_index][0],
                                                                                     data[max_row_index][4],
                                                                                     data[max_row_index][3]))
print("The standard deviation of flat sold/rented is {:.0f}".format(std))
print("The Variance of flat sold/rented is  {:.0f}".format(var))

#Sorted Rented
print()
def rented(data):
    data_rented = data[data['sold_or_rented']=='rented']
    return data_rented

max_value = np.max(rented(data)['no_of_units'])
max_row_index = np.argmax(rented(data)['no_of_units'])

 
std = np.std(rented(data)['no_of_units'])
var = np.var(rented(data)['no_of_units'])

print()

print("The mean number of flat rented over the years is {:.0f}".format(np.mean(rented(data)['no_of_units'])))
print("The maximum number of flat rented was in the year {} is {} on {}".format(rented(data)[max_row_index][0],
                                                                                rented(data)[max_row_index][4],
                                                                                rented(data)[max_row_index][3]))
print("The standard deviation of flat rented is {:.0f}".format(std))
print("The Variance of flat rented is {:.0f}".format(var))

#Sorted Sold
def sold(data):
    data_sold = data[data['sold_or_rented']=='sold']
    return data_sold



max_value = np.max(sold(data)['no_of_units'])
max_row_index = np.argmax(sold(data)['no_of_units'])

 
std = np.std(sold(data)['no_of_units'])
var = np.var(sold(data)['no_of_units'])

print()

print("The mean number of flat sold over the years is {:.0f}".format(np.mean(sold(data)['no_of_units'])))
print("The maximum number of flat sold was in the year {} is {} on {}".format(sold(data)[max_row_index][0],
                                                                              sold(data)[max_row_index][4],
                                                                              sold(data)[max_row_index][3]))
print("The standard deviation of flat sold is {:.0f}".format(std))
print("The Variance of flat sold is {:.0f}".format(var))
# Out:
# ***Number of Sold and Rented Residential Units***
#
# There are 180 rows in this dataset
#
# 9 unique values in year column
# 2 unique values in property_type column
# 2 unique values in sold_or_rented column
# 7 unique values in flat_type column
# 94 unique values in no_of_units column
#
# The mean number of flat sold/rented over the years is 754
# The maximum number of flat sold/rented was in the year 2014 is 11414 on 4-room flats
# The standard deviation of flat sold/rented is 1568
# The Variance of flat sold/rented is  2459477
#
#
# The mean number of flat rented over the years is 348
# The maximum number of flat rented was in the year 2012 is 2734 on 1-room flats
# The standard deviation of flat rented is 662
# The Variance of flat rented is 438330
#
# The mean number of flat sold over the years is 1150
# The maximum number of flat sold was in the year 2014 is 11414 on 4-room flats
# The standard deviation of flat sold is 2029
# The Variance of flat sold is 4118161

# %%
#Take Number of Units from different House Type
def change_barchart_type(change):
    ax2.clear()

    for i in range(len(type_options)):
        if(change['new'] != 'Total'):
            changed_data = data[data['flat_type']==change['new']]
        else:
            changed_data = data
    rented(changed_data)
    sold(changed_data)
    plotbar(create_xaxis (1,2,len(set_year),0.8),rented_by_year(rented(changed_data)),'b',
            create_xaxis (2,2,len(set_year),0.8),sold_by_year(sold(changed_data)),'y')#Rented 1st bar Sold 2nd bar
                
def plotbar(x1,y1,c1,x2,y2,c2):
    
    ax2.bar(x1,y1,color=c1) #Rented 1st bar 
    ax2.bar(x2,y2,color=c2) #Sold 2nd bar

    
    #Putting the Bar together
    ax2.set_xticks([ (a + b) / 2.0 for a, b in zip(create_xaxis (1,2,len(set_year),0.8), create_xaxis (2,2,len(set_year),0.8))])
    ax2.set_xticklabels(set_year)
    ax2.legend(["Rented", "Sold"])
    plt.title('Different between Rented and Sold Units by Year')
    plt.ylabel('Number of Units')
    plt.xlabel('Year')
    ax2.yaxis.grid(True)
    
#total for year rented
def rented_by_year(data):
    rented_by_year = []
    for i in range(len(set_year)):
        rented_by_year.append(np.sum(data[data['year'] == list(set_year)[i] ]['no_of_units']))
    rented_by_year = np.array(rented_by_year)
    return rented_by_year

#total for year sold
def sold_by_year(data):
    sold_by_year = []
    for i in range(len(set_year)):
        sold_by_year.append(np.sum(data[data['year']== list(set_year)[i] ]['no_of_units']))
    sold_by_year = np.array(sold_by_year)
    return sold_by_year

#Creating Graph
def create_xaxis(n,t,d,w):
    # n = Dataset out of n | t = Number of datasets | d = Number of sets of bars | w = Width of each bar
    return [t*x + w*n for x in range(d)]

#ax2 Object (bar chart year to unit)
fig = plt.figure(figsize=(9,5))
ax2 = fig.add_subplot(111)

plotbar(create_xaxis (1,2,len(set_year),0.8),rented_by_year(rented(data)),'b'
       ,create_xaxis (2,2,len(set_year),0.8),sold_by_year(sold(data)),'y')#Rented 1st bar #Sold 2nd bar


#Take away Warning
warnings.filterwarnings("ignore",category=matplotlib.cbook.mplDeprecation)

#Combo Box selection (Type of houses)
type_options = sorted(set_flat_type)
type_options.append('Total')
type_cb = widgets.Dropdown(options=type_options,value=type_options[-1],
                  description='Type of Flats:',
                  style= {'description_width': 'initial'} )
type_cb.observe(change_barchart_type,names="value")
display(type_cb)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">
# Dropdown(description='Type of Flats:', index=7, options=('1-room flats', '2-room flats', '3-room flats', '4-room flats', '5-room flats', 'Executive/Multi-Generation flats', 'Studio Apartments', 'Total'), style=DescriptionStyle(description_width='initial'), value='Total')

# %% [markdown]
# # Different between Rented and Sold Units by House Type (Bar Chart)

# %%
def change_barchart2_year(change):
    ax3.clear()
    for i in range(len(year_options)):
        if(change['new'] != 'All'):
            changed_data = data[data['year'] == change['new']]
        else:
            changed_data = data
    rented(changed_data)
    sold(changed_data)
    plotbar2(   create_xaxis (1,2,len(set_flat_type),0.8), rented_by_type(rented(changed_data)),'b',
                create_xaxis (2,2,len(set_flat_type),0.8), sold_by_type(sold(changed_data))    ,'y') #Rented 1st bar #Sold 2nd bar
    
def plotbar2(x1,y1,c1,x2,y2,c2):
    ax3.bar(x1,y1,color=c1) #Rented 1st bar 
    ax3.bar(x2,y2,color=c2) #Sold 2nd bar
    #Putting the Bar together
    ax3.set_xticks([ (a + b) / 2.0 for a, b in zip(create_xaxis (1,2,len(set_flat_type),0.8), create_xaxis (2,2,len(set_flat_type),0.8))])
    ax3.set_xticklabels(type_of_flats)
    ax3.legend(["Rented", "Sold"])
    plt.title('Different between Rented and Sold Units by Type of Houses')
    plt.ylabel('Number of Units')
    plt.xlabel('Type of Flats')
    ax3.yaxis.grid(True)
    fig.autofmt_xdate()

#type of flats
type_of_flats = list(set_flat_type)
type_of_flats.sort()


#total for each type rented
def rented_by_type(data):
    rented_by_type = []
    for i in range(len(set(data['flat_type']))):
        rented_by_type.append(np.sum(data[data['flat_type'] == type_of_flats[i:i+1]]['no_of_units']))
    rented_by_type = np.array(rented_by_type)
    return rented_by_type

#total for each type sold
def sold_by_type(data):
    sold_by_type = []
    for i in range(len(set(data['flat_type']))):
        sold_by_type.append(np.sum(data[data['flat_type'] == type_of_flats[i:i+1]]['no_of_units']))
    sold_by_type = np.array(sold_by_type)
    return sold_by_type

fig = plt.figure(figsize=(10,8))
ax3 = fig.add_subplot(111)

#ax3 Object (bar chart type to unit)
plotbar2(   create_xaxis (1,2,len(set_flat_type),0.8), rented_by_type(rented(data)),'b',
            create_xaxis (2,2,len(set_flat_type),0.8), sold_by_type(sold(data))    ,'y') #Rented 1st bar #Sold 2nd bar

#Combo Box selection (Year)
year_options = sorted(set_year)
year_options.append('All')
year_cb = widgets.Dropdown(options=year_options,value=year_options[-1],
                  description='Year:',
                  style= {'description_width': 'initial'} )
year_cb.observe(change_barchart2_year,names="value")
display(year_cb)

warnings.filterwarnings("ignore",category=matplotlib.cbook.mplDeprecation)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Dropdown(description='Year:', index=9, options=(2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 'All'), style=DescriptionStyle(description_width='initial'), value='All')

# %% [markdown]
# # 1990 - 2018 Data on Resale Flat Price (Data)

# %%
title = "Resale Flat Prices"
titlelen = len(title)
print("{:*^{titlelen}}".format(title, titlelen=titlelen+6))
print()

data_1 = np.genfromtxt('DataProject/Resale/1resale-flat-prices-based-on-approval-date-1990-1999.csv',  
                skip_header=1, 
                dtype=[('date','U7'),  ('town','U50'), ('flat_type','U50'), 
                       ('block','U50'), ('street_name','U50'),('storey_range','U50'),
                       ('floor_area_sqm','i4'),('flat_model','U50'),('lease_commence_date','i4'),
                       ('resale_price','i4')], delimiter=",",
                        missing_values=['na'],filling_values=0)

data_2 = np.genfromtxt('DataProject/Resale/2resale-flat-prices-based-on-approval-date-2000-feb-2012.csv',  
                skip_header=1, 
                dtype=[('date','U7'),  ('town','U50'), ('flat_type','U50'), 
                       ('block','U50'), ('street_name','U50'),('storey_range','U50'),
                       ('floor_area_sqm','i4'),('flat_model','U50'),('lease_commence_date','i4'),
                       ('resale_price','i4')], delimiter=",",
                        missing_values=['na'],filling_values=0)
data_3 = np.genfromtxt('DataProject/Resale/3resale-flat-prices-based-on-registration-date-from-mar-2012-to-dec-2014.csv',  
                skip_header=1, 
                dtype=[('date','U7'),  ('town','U50'), ('flat_type','U50'), 
                       ('block','U50'), ('street_name','U50'),('storey_range','U50'),
                       ('floor_area_sqm','i4'),('flat_model','U50'),('lease_commence_date','i4'),
                       ('resale_price','i4')], delimiter=",",
                        missing_values=['na'],filling_values=0)

#special got remaining lease unlike others resale flat data, so i have to remove remaining_lease column
ignore=[9] #9 = remaining_lease column
data_4_wanted_column = [ind for ind in range(11) if ind not in ignore] #Not counting removing remaining_lease column
data_4 = np.genfromtxt('DataProject/Resale/4resale-flat-prices-based-on-registration-date-from-jan-2015-onwards.csv',  
                skip_header=1, 
                dtype=[('date','U7'),  ('town','U50'), ('flat_type','U50'), 
                       ('block','U50'), ('street_name','U50'),('storey_range','U50'),
                       ('floor_area_sqm','i4'),('flat_model','U50'),('lease_commence_date','i4'),
                       ('resale_price','i4')], delimiter=",",usecols = (data_4_wanted_column),
                        missing_values=['na'],filling_values=0)

data = np.concatenate([data_1,data_2,data_3,data_4])

#there is 2 type of MULTI-GENERATION/MULTI GENERATION
for i in range(len(data)):
    if(data['flat_type'][i]== 'MULTI-GENERATION'):
        data['flat_type'][i] = 'MULTI GENERATION'


set_date               = set(data['date'])
set_town               = set(data['town'])
set_flat_type          = set(data['flat_type']) 
set_block              = set(data['block'])
set_street_name        = set(data['street_name'])
set_storey_range       = set(data['storey_range'])           
set_floor_area_sqm     = set(data['floor_area_sqm'])           
set_flat_model         = set(data['flat_model'])           
set_lease_commence_date= set(data['lease_commence_date'])           
set_resale_price       = set(data['resale_price'])  

print("There are {} rows in this dataset".format(len(data)))

#Towns
town = np.array(list(set_town))
town.sort()

print()
         
print(str(len(set_date               )) + " unique values in date column")
print(str(len(set_town               )) + " unique values in town column")
print(str(len(set_flat_type          )) + " unique values in flat_type column")
print(str(len(set_block              )) + " unique values in block column")
print(str(len(set_street_name        )) + " unique values in street_name column")
print(str(len(set_storey_range       )) + " unique values in storey_range column")
print(str(len(set_floor_area_sqm     )) + " unique values in floor_area_sqm column")
print(str(len(set_flat_model         )) + " unique values in flat_model column")
print(str(len(set_lease_commence_date)) + " unique values in lease_commence_date column")
print(str(len(set_resale_price       )) + " unique values in resale_price column")


#Unique Year
resale_year = []
for i in range(len(set_date)):
    resale_year.append(int(list(set_date)[i][0:4]))
resale_year = np.array(resale_year)
set_resale_year = set(resale_year)
print("There is {} unique years ".format(str(len(set_resale_year))))


max_value = np.max(data['resale_price'])
min_value = np.min(data['resale_price'])  

max_row_index = np.argmax(data['resale_price'])
min_row_index = np.argmin(data['resale_price'])
 
std = np.std(data['resale_price'])
var = np.var(data['resale_price'])

print()

print("The mean price of Resale Flat Prices over the years is ${:.2f}".format(np.mean(data['resale_price'])))
print("The maximum price of Resale Flat Prices was in year {} is ${} at {}".format(data[max_row_index][0],data[max_row_index][-1],data[max_row_index][1]))
print("The minimum price of Resale Flat Prices was in year {} is ${} at {}".format(data[min_row_index][0],data[min_row_index][-1],data[min_row_index][1]))
print("The standard deviation of Resale Flat Prices is ${:.2f}".format(std))
print("The Variance of Resale Flat Prices is  ${:.2f}".format(var))
# Out:
# ***Resale Flat Prices***
#
# There are 769807 rows in this dataset
#
# 338 unique values in date column
# 27 unique values in town column
# 7 unique values in flat_type column
# 2196 unique values in block column
# 546 unique values in street_name column
# 25 unique values in storey_range column
# 184 unique values in floor_area_sqm column
# 34 unique values in flat_model column
# 50 unique values in lease_commence_date column
# 8016 unique values in resale_price column
# There is 29 unique years
#
# The mean price of Resale Flat Prices over the years is $282567.15
# The maximum price of Resale Flat Prices was in year 2017-02 is $1180000 at BISHAN
# The minimum price of Resale Flat Prices was in year 1990-07 is $5000 at BUKIT MERAH
# The standard deviation of Resale Flat Prices is $142614.16
# The Variance of Resale Flat Prices is  $20338797587.86

# %% [markdown]
# # 1990 - 2018 Data on Resale Flat Price (Histogram)

# %%
fig = plt.figure(figsize=(10,8))
ax4 = fig.add_subplot(111)
flat_type_resale  = list(set_flat_type)
flat_type_resale.sort()
for i in range(len(set_flat_type)):
    ax4.hist(data[data['flat_type'] == flat_type_resale[i:i+1]]['resale_price'],alpha = 0.5,label = flat_type_resale[i:i+1])
plt.title('Resale Price from 1990 - 2018')
plt.ylabel('Frequency')
plt.xlabel('Resale Price')
ax4.legend(loc=7)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
fig = plt.figure(figsize=(10,8))
ax5 = fig.add_subplot(111)
flat_type_resale  = list(set_flat_type)
flat_type_resale.sort()
for i in range(len(set_flat_type)):
    ax5.hist(data_4[data_4['flat_type'] == flat_type_resale[i:i+1]]['resale_price'],alpha = 0.5,label = flat_type_resale[i:i+1])
plt.title('Resale Price from 2015 - 2018')
plt.ylabel('Frequency')
plt.xlabel('Resale Price')
ax5.legend(loc=7)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# # 1990 - 2018 Data on Resale Flat Price (Scatterplot)

# %%
fig = plt.figure(figsize=(10,8))
ax6 = fig.add_subplot(111)
ax6.scatter(data['resale_price'],data['floor_area_sqm'])
plt.title('Resale Price affected by floor_area_sqm')
plt.ylabel('Floor Area(sqm)')
plt.xlabel('Resale Price')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
fig = plt.figure(figsize=(10,8))
ax7 = fig.add_subplot(111)
ax7.scatter(data_4['resale_price'],data_4['floor_area_sqm'])
plt.title('Resale Price affected by floor_area_sqm')
plt.ylabel('Floor Area(sqm)')
plt.xlabel('Resale Price')
plt.show()
# Out:
# <div id='fe3f3fea-380f-4cc8-be3f-023832f78cc4'></div>

# %% [markdown]
# # 1990 - 2018 Data on Resale Flat Price (Boxplot)

# %%
#resale price and arrange it so that boxplot can use
resale_price_by_array = []

for i in range(len(set(data['town']))):
    buffer = np.array([(data[data['town'] == town[i:i+1]]['resale_price'])])
    resale_price_by_array.append(sum(buffer))
    
resale_price_by_array = np.array(resale_price_by_array)

fig = plt.figure(figsize=(10,8))
ax8 = fig.add_subplot(111)
#ax8 Object (bar chart type to unit)
ax8.boxplot(resale_price_by_array,1)


ax8.set_xticklabels(town)

plt.title('Resale Price on different Town')
plt.ylabel('Resale Price')
plt.xlabel('Town')

warnings.filterwarnings("ignore",category=matplotlib.cbook.mplDeprecation)
fig.autofmt_xdate()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
#resale price and arrange it so that boxplot can use
resale_price_by_array = []

for i in range(len(set(data_4['town']))):
    buffer = np.array([(data_4[data_4['town'] == town[i:i+1]]['resale_price'])])
    resale_price_by_array.append(sum(buffer))
    
resale_price_by_array = np.array(resale_price_by_array)

fig = plt.figure(figsize=(10,8))
ax9 = fig.add_subplot(111)

#ax6 Object (bar chart type to unit)
plt.boxplot(resale_price_by_array,1)
ax9 = plt.subplot()

ax9.set_xticklabels(town)

plt.title('Resale Price on different Town')
plt.ylabel('Resale Price')
plt.xlabel('Town')

warnings.filterwarnings("ignore",category=matplotlib.cbook.mplDeprecation)
fig.autofmt_xdate()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
print(data)
# Out:
# [('1990-01', 'ANG MO KIO', '1 ROOM', '309', 'ANG MO KIO AVE 1', '10 TO 12',  31, 'IMPROVED', 1977,   9000)
#  ('1990-01', 'ANG MO KIO', '1 ROOM', '309', 'ANG MO KIO AVE 1', '04 TO 06',  31, 'IMPROVED', 1977,   6000)
#  ('1990-01', 'ANG MO KIO', '1 ROOM', '309', 'ANG MO KIO AVE 1', '10 TO 12',  31, 'IMPROVED', 1977,   8000)
#  ...
#  ('2018-02', 'YISHUN', 'EXECUTIVE', '723', 'YISHUN ST 71', '04 TO 06', 146, 'Maisonette', 1986, 570000)
#  ('2018-02', 'YISHUN', 'EXECUTIVE', '877', 'YISHUN ST 81', '04 TO 06', 142, 'Apartment', 1987, 580000)
#  ('2018-02', 'YISHUN', 'EXECUTIVE', '877', 'YISHUN ST 81', '10 TO 12', 142, 'Apartment', 1987, 645000)]
